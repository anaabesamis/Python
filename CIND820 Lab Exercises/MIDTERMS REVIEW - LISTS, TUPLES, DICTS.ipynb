# %%
first = [1,[10,20,[100,200,300]]]
second = [4,5,[.4,.5,.6,.7],6,7]

print(first[1])
print(second[2:5])
print(len(second))
print(range(len(second)))
print(first[1][0] > second[4])
print(first[1][2] + second[2])
# Out:
# [10, 20, [100, 200, 300]]
# [[0.4, 0.5, 0.6, 0.7], 6, 7]
# 5
# range(0, 5)
# True
# [100, 200, 300, 0.4, 0.5, 0.6, 0.7]

# %%
bp = ['B','L','A','C','K','P','I','N','K']
bp.append(4)
bp.extend([5])
bp.append([9])
bp.insert(9,[630])
bp.sort()
#bp.pop(bp.index([4]))
print(bp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-6b22fe3dcb65> in <module>()
#       4 bp.append([9])
#       5 bp.insert(9,[630])
# ----> 6 bp.sort()
#       7 #bp.pop(bp.index([4]))
#       8 print(bp)
#
# TypeError: '<' not supported between instances of 'list' and 'str'

# %%
strr = "bts"
listt = [1,2,3,4]
tupp = (5,6,7,8)

# %%
avar = [1,3,5]
bvar = avar

avar = avar + [2]
print(avar)
print(bvar)
# Out:
# [1, 3, 5, 2]
# [1, 3, 5]

# %%
adict = {}
adict[(55,179)] = 'value'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-525e7dd52398> in <module>()
#       2 adict[(55,179)] = 'value'
#       3
# ----> 4 print(adict(55))
#
# TypeError: 'dict' object is not callable

# %%
data = [5,3,7]

data.sort()

print(data)
# Out:
# [3, 5, 7]

# %% [markdown]
# Write a loop that accumulates the sum of the numbers in a list named data.

# %%
sum = 0

for num in data:
  sum = sum + num

print(sum)
# Out:
# 15

# %%
data = {'b':20, 'a':35}

print(data['a'])
print(data.get('c',None))
print(len(data))
print(data.keys())
print(data.values())

data['d'] = -20
data['c'] = 40

keys = list(data.keys())
keys.sort()
for key in keys:
  print(key,data[key])
# Out:
# 35
# None
# 2
# dict_keys(['b', 'a'])
# dict_values([20, 35])
# a 35
# b 20
# c 40
# d -20
