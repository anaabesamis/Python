# %% [markdown]
# # **LAB 10<br>**
# **1 - BINARY TREE IMPLEMENTATIONS**<br>
# b. List the difference between the complete binary tree and the perfectly balanced binary tree.<br>
# c. List the difference between the full binary tree and the complete binary tree.<br>
# d. How many nodes does each of the following binary trees contain?<br>
# i. A complete binary tree with a height equal to 3.<br>
# ii. A full binary tree with a height equal to 99.<br>
# e. What is the height of each of the following full binary trees?<br>
# i. A full binary tree with 15 nodes.<br>
# ii. A full binary tree with 31 nodes.

# %%
# Difference between complete binary tree and perfectly balanced binary tree:
'''The complete BT can be a perfectly balanced BT where the nodes on the last
level are filled-in from left to right. However, the perfectly balanced BT is
not always complete, as each level is filled in with nodes except the last.'''

# Difference between full binary tree and complete binary tree
'''The full BT is a complete BT where the nodes on the last level are entirely
filled-in. However, the nodes on the last level of a complete BT might not be
fully filled-in all the time.'''

# How many nodes
# Complete BT, height = 3
''' Min number = 2^3 = 8
    Max number = 2^(3+1) - 1 = 15'''
# Full BT, height = 99
''' 2^(99+1) - 1 = 1.27e30'''

# What is the height
# Full BT, nodes = 15
'''log2(15+1)-1 = 3'''

# Full BT, nodes = 31
'''log2(31+1)-1 = 4'''

# %% [markdown]
# **2 - BINARY TREE APPLICATIONS AND TRAVERSALS**<BR>
# b. Given the following pre-order traversal algorithm that visits the root node, then traverses the left
# subtree and the right subtree similarly.<BR><br>
# Algorithm preOrderBT(Tree, Root):<br>
# Visit the node at position 'Root'<br>
# for 'Child' in 'Tree.children(Root)':<br>
# preOrderBT(Tree, Child)<br><BR>
# Write down the visited nodes’ sequence if we apply that algorithm on the binary trees in question
# 1a.

# %% [markdown]
# c. Given the following post-order traversal algorithm that can be viewed as the opposite of the pre-
# order traversal algorithm.<br><br>
# Algorithm postOrderBT(Tree, Root):<br>
# for 'Child' in 'Tree.children(Root)':<br>
# postOrderBT(Tree, Child)<br>
# Visit the node at position 'Root'<br><br>
# Write down the visited nodes’ sequence if we apply that algorithm on the full binary tree in question
# 1a

# %% [markdown]
# d. In pseudo-code, describe an algorithm that visits the nodes of the binary trees in question 2a to
# form the corresponding arithmetic expression. Then show the traversal paths that will be taken
# upon applying that algorithm on those binary trees
